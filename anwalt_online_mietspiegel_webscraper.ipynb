# %%
import bs4 as bs
import urllib.request
import time
from datetime import datetime
import pandas as pd
import numpy as np
import json
import os
import pickle

# %%
path_abs = os.path.abspath('.')

# %%
def load_MietspiegelInfo(path):
    df_metaInfos = pd.read_csv(path)
    df_metaInfos.rename(columns={'Vergleichsmiete für 65m²-Wohnungen*': 'Stadt', 
                            'Baujahr':'PLZ', 
                            '€/m²': 'Aktualität'}, inplace=True)
    return df_metaInfos

# %%
def load_MietspiegelURL(path):
    df_metaURLs = pd.read_csv(path)
    return df_metaURLs

# %%
def load_mietspiegel(url):
    data = urllib.request.urlopen(url)
    data = data.read()
    soup = bs.BeautifulSoup(data,'lxml')
    
    constYear = []
    sqrPrice = []
    counter = 0
    cut = None
    VergleichsmieteForflatSize = None
    df01 = None
    df02 = None
    comment = soup.find_all('div', {'class': 'InhaltContent'})
    
    if not comment:
        try:
            for idx,entry in enumerate(soup.find_all('td')):
                if counter == 0:
                    if entry.text.strip():
                        cut = int(idx/3)
                        if not VergleichsmieteForflatSize:
                            VergleichsmieteForflatSize = entry.text
                        continue
                if counter == 1:
                    constYear.append(entry.text)
                if counter == 2:
                    sqrPrice.append(entry.text.replace('\n',''))

                counter += 1
                if counter == 3:
                    counter = 0

            if len(sqrPrice) != len(constYear):
                print('Check this URL: ' + url)

            colNames = []
            for headline in soup.find_all('th'):
                colNames.append(headline.text)

            df01 = pd.DataFrame(columns = colNames)
            df01.iloc[:,1] = constYear[:cut]
            df01.iloc[:,2] = sqrPrice[:cut]

            colNames[0] = VergleichsmieteForflatSize
            df02 = pd.DataFrame(columns = colNames)
            df02.iloc[:,1] = constYear[cut:]
            df02.iloc[:,2] = sqrPrice[cut:]
        except:
            print('Attention: Here is a problem! URL: ' + url)
            comment = 'FEHLER'
    
    return df01, df02, comment

# %%
def load_mietspiegel_raw(url):
    data = urllib.request.urlopen(url)
    data = data.read()
    soup = bs.BeautifulSoup(data,'lxml')
    
    constYear = []
    sqrPrice = []
    counter = 0
    cut = None
    VergleichsmieteForflatSize = None
    df01 = None
    df02 = None
    
    for idx,entry in enumerate(soup.find_all('td')):
        if counter == 0:
            if entry.text.strip():
                cut = int(idx/3)
                if not VergleichsmieteForflatSize:
                    VergleichsmieteForflatSize = entry.text
                continue
        if counter == 1:
            constYear.append(entry.text)
        if counter == 2:
            sqrPrice.append(entry.text.replace('\n',''))

        counter += 1
        if counter == 3:
            counter = 0

    if len(sqrPrice) != len(constYear):
        print('Check this URL: ' + url)

    colNames = []
    for headline in soup.find_all('th'):
        colNames.append(headline.text)

    df01 = pd.DataFrame(columns = colNames)
    df01.iloc[:,1] = constYear[:cut]
    df01.iloc[:,2] = sqrPrice[:cut]

    colNames[0] = VergleichsmieteForflatSize
    df02 = pd.DataFrame(columns = colNames)
    df02.iloc[:,1] = constYear[cut:]
    df02.iloc[:,2] = sqrPrice[cut:]
    
    return df01, df02, comment

# %%
def executer(storage, df_metaInfos, df_metaURLs):
    df_comment = pd.DataFrame(df_metaURLs.shape[0] * [np.nan], columns = ['Bemerkung'])
    for idx,url in enumerate(df_metaURLs.URL):
        print(str(idx) + ': ' + url)
        storage[df_metaURLs.iloc[idx,0]] = []
        df01, df02, comment = load_mietspiegel(url)
        if df01 is not None:
            storage[df_metaURLs.iloc[idx,0]].append(df01) 
        if df02 is not None:
            storage[df_metaURLs.iloc[idx,0]].append(df02) 
        if comment:
            if type(comment) is str:
                df_comment.iloc[idx,0] = comment
            else:
                df_comment.iloc[idx,0] = comment[0].text
    df_metaInfos.insert(3, 'Bemerkung', df_comment.values)
    return df_metaInfos, storage

# %%
file_names_MetaInfo = ['/anwaltonlineMietspiegelInfo01.csv', 
                      '/anwaltonlineMietspiegelInfo02.csv', 
                      '/anwaltonlineMietspiegelInfo03.csv', 
                      '/anwaltonlineMietspiegelInfo04.csv', 
                      '/anwaltonlineMietspiegelInfo05.csv', 
                      '/anwaltonlineMietspiegelInfo06.csv', 
                      '/anwaltonlineMietspiegelInfo07.csv']

file_names_URL = ['/anwaltonlineMietspiegelURLs01.csv', 
                  '/anwaltonlineMietspiegelURLs02.csv', 
                  '/anwaltonlineMietspiegelURLs03.csv', 
                  '/anwaltonlineMietspiegelURLs04.csv', 
                  '/anwaltonlineMietspiegelURLs05.csv', 
                  '/anwaltonlineMietspiegelURLs06.csv', 
                  '/anwaltonlineMietspiegelURLs07.csv']

# %%
storage = {}
df_metaInfosFinal = None
for i in range(7):
    path_metaInfos = path_abs + file_names_MetaInfo[i]
    df_metaInfosRaw = load_MietspiegelInfo(path_metaInfos)
    path_URLs = path_abs + file_names_URL[i]
    df_metaURLs = load_MietspiegelURL(path_URLs)
    
    df_metaInfos, storage = executer(storage, df_metaInfosRaw, df_metaURLs)
    if df_metaInfosFinal is None:
        df_metaInfosFinal = df_metaInfos
    else:
        df_metaInfosFinal = pd.concat([df_metaInfosFinal, df_metaInfos], axis=0)
        df_metaInfosFinal = df_metaInfosFinal.reset_index(drop=True)

# %%
df01, df02, comment = load_mietspiegel_raw('https://www.anwaltonline.com/mietrecht/mietspiegel/122/dinslaken')
storage['Dinslaken'] = [df01, df02]

# %% [markdown]
# ## Cleaning Data

# %%
path_mietspiegelInfo = path_abs+'/metaInfosAll.csv'
df_mietspiegelLookUp = pd.read_csv(path_mietspiegelInfo, index_col=0)

# %%
df_mietspiegelLookUp
# Out:
#                           Stadt            PLZ  Aktualität  \
# 0                        Aachen          52080  01.01.2017
# 1                         Aalen          73434  01.02.2018
# 2                     Abensberg          93326  01.01.2001
# 3                         Ahaus          48683  01.01.2019
# 4                         Ahlen  59227 - 59229  01.01.2010
# 5                    Aichhalden          78733  01.01.2018
# 6                       Albaxen          37671         NaN
# 7          Aldenhofen, Gemeinde          52457         NaN
# 8                    Allersberg          90584         NaN
# 9                         Alpen          46519  01.01.2017
# 10                      Alsdorf          52477  01.01.2018
# 11       Altdorf (Niederbayern)          84032  01.01.2016
# 12         Altdorf bei Nürnberg          90518  01.01.2000
# 13            Altdorf, Gemeinde          72655         NaN
# 14     Altdorf, Kreis Böblingen          71155  01.01.2016
# 15                       Altena          58762  01.01.2016
# 16                    Altenburg          04600  01.01.2014
# 17      Altenkirchen, Landkreis          57610  01.07.2014
# 18                     Althütte          71566         NaN
# 19                    Altötting          84503         NaN
# 20                   Altshausen          88361         NaN
# 21                    Altusried          87452         NaN
# 22                      Amtzell          88279         NaN
# 23                    Andernach          56626  01.01.1996
# 24                   Angermünde          16278  01.07.2014
# 25                     Anröchte          59609         NaN
# 26                      Ansbach          91522         NaN
# 27                Arnoldsweiler          52353  01.08.2007
# 28                     Arnsberg  59755 - 59823  01.01.2011
# 29                      Arzberg          95659  01.01.2017
# ..                          ...            ...         ...
# 660                 Wiggensbach          87487         NaN
# 661               Wildpoldsried          87499         NaN
# 662  Wilhelmsdorf (Württemberg)          88271         NaN
# 663                     Willich          47877  01.01.2017
# 664                   Wilnsdorf          57234  01.04.2009
# 665                   Winnenden          71364  28.06.2016
# 666               Winsen (Luhe)          21423  01.12.1994
# 667        Winterbach (Remstal)          73650         NaN
# 668                  Winterberg          59955         NaN
# 669                 Wipperfürth          51688  01.01.2017
# 670                      Wismar  23966 - 23970  01.02.2016
# 671                      Wissen          57537         NaN
# 672                      Witten  58452 - 58456  01.03.2018
# 673                Wolfschlugen          72649         NaN
# 674                  Wollenberg          74906         NaN
# 675               Wolpertswende          88284         NaN
# 676                       Worms  67547 - 67551  01.01.2016
# 677                    Wülfrath          42489  01.01.2009
# 678       Wünschendorf (Elster)          07570         NaN
# 679                   Wunsiedel          95632  01.01.2017
# 680                    Wunstorf          31515  01.03.2019
# 681                   Wuppertal  42103 - 42399  22.12.2018
# 682                    Würselen          52146  01.04.2016
# 683                    Würzburg  97070 - 97084  01.01.2012
# 684                      Xanten          46509  01.01.2017
# 685                  Zeulenroda  07937 - 07950         NaN
# 686                   Zimmerhof          74906         NaN
# 687                    Zirndorf          90513  01.01.2017
# 688                     Zülpich          53909  01.10.2007
# 689                     Zwickau  08056 - 08066  01.05.2017
#
#                                              Bemerkung
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6    Für Albaxen ist mit Abschlag von 5 Prozent der...
# 7    Für die Gemeinde Aldenhoven gibt es keinen eig...
# 8                                               FEHLER
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13   Es kommt der Mietspiegel von Schorndorf zur An...
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18   Die Gemeinde Althütte ist dem Mietspiegel der ...
# 19                                              FEHLER
# 20   Für Altshausen kommt der Mietspiegel des Landk...
# 21                                              FEHLER
# 22   Für Amtzell kommt der Mietspiegel des Landkrei...
# 23                                                 NaN
# 24                                                 NaN
# 25   Für die Gemeinde Anröchte ist mit Abschlägen v...
# 26                                              FEHLER
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 660                                             FEHLER
# 661                                             FEHLER
# 662  Für Wilhelmsdorf kommt der Mietspiegel des Lan...
# 663                                                NaN
# 664                                                NaN
# 665                                                NaN
# 666                                                NaN
# 667  Für Winterbach kommt der Mietspiegel von Schor...
# 668  Es kommt der Mietspiegel für den Hochsauerland...
# 669                                                NaN
# 670                                                NaN
# 671  Für Wissen kommt der Mietspiegel von Altenkirc...
# 672                                                NaN
# 673  Die Gemeinde Wolfschlugen hat keinen Mietspieg...
# 674  Es kommt der Mietspiegel von Heilbronn mit 25%...
# 675  Für Wolpertswende kommt der Mietspiegel des La...
# 676                                                NaN
# 677                                                NaN
# 678  Es kommt der Mietspiegel des Landkreises Greiz...
# 679                                                NaN
# 680                                                NaN
# 681                                                NaN
# 682
# 683                                                NaN
# 684                                                NaN
# 685  Es kommt der Mietspiegel des Landkreises Greiz...
# 686  Es kommt der Mietspiegel von Heilbronn kommt m...
# 687                                                NaN
# 688                                                NaN
# 689                                                NaN
#
# [690 rows x 4 columns]

# %% [markdown]
# **2DO:**
# Aufspalten der Bindestrichpostleitzahlen in einzelne Postleitzahl

# %%
plz_with_ranges = df_mietspiegelLookUp.PLZ.loc[df_mietspiegelLookUp.PLZ.str.len() > 5]
for idx,plz_range in enumerate(plz_with_ranges):
    from_until = [int(x) for x in plz_range.split(' - ')]
    df_idx = int(plz_with_ranges.index[idx])
    current_row = df_mietspiegelLookUp.iloc[df_idx,:]
    current_row.PLZ = str(from_until[0])
    df_mietspiegelLookUp.iloc[df_idx, :] = current_row
    
df_mietspiegelLookUp.PLZ = df_mietspiegelLookUp.PLZ.astype('int')

# %%
df_mietspiegelLookUp.sort_values('PLZ')
# Out:
#                            Stadt    PLZ  Aktualität  \
# 145                      Dresden   1067  01.01.2019
# 487                     Radebeul   1445  01.12.2017
# 224                   Großenhain   1558  01.01.2017
# 507                        Riesa   1587  01.07.2016
# 125             Coswig (Sachsen)   1640  01.01.2017
# 396                       Meißen   1662  01.01.2013
# 479                        Pirna   1796  01.01.2018
# 61                       Bautzen   2625  01.09.2017
# 217                      Görlitz   2826  01.09.1999
# 282                  Hoyerswerda   2977  01.11.2008
# 126                      Cottbus   3042  01.01.2011
# 572                    Spremberg   3130  01.07.1997
# 226                        Guben   3172  01.01.2000
# 121                        Calau   3205         NaN
# 352                      Leipzig   4103  23.11.2017
# 16                     Altenburg   4600  01.01.2014
# 140                       Döbeln   4720  01.03.2000
# 46              Bad Liebenwerder   4924         NaN
# 237                Halle (Saale)   6108  01.01.2010
# 76              Bernburg (Saale)   6406  01.07.1999
# 32                  Aschersleben   6449  01.01.2008
# 419             Naumburg (Saale)   6618  23.01.2019
# 640                   Weißenfels   6667  01.01.2012
# 134                Dessau-Roßlau   6842  01.01.2014
# 301              Jessen (Elster)   6917  01.01.1997
# 524             Saalfeld (Saale)   7318  01.01.2017
# 522                   Rudolstadt   7407  01.06.2010
# 207                         Gera   7545  01.08.2017
# 438               Niederpöllnitz   7570         NaN
# 678        Wünschendorf (Elster)   7570         NaN
# ..                           ...    ...         ...
# 584                    Straubing  94315  01.07.2016
# 275                          Hof  95028  01.06.2018
# 558                         Selb  95100  01.01.2017
# 319                Kirchenlamitz  95158  01.01.2017
# 641                  Weißenstadt  95163  01.01.2017
# 388                 Marktleuthen  95168  01.01.2017
# 541                    Schönwald  95173  01.01.2017
# 273  Höchstädt im Fichtelgebirge  95186  01.01.2017
# 514                       Röslau  95195  01.01.2017
# 597                   Thierstein  95199  01.01.2015
# 62                      Bayreuth  95444         NaN
# 389                 Marktredwitz  95615  01.01.2017
# 679                    Wunsiedel  95632  01.01.2017
# 29                       Arzberg  95659  01.01.2017
# 40             Bad Alexandersbad  95680  01.01.2017
# 277        Hohenberg an der Eger  95691  01.01.2017
# 418                        Nagel  95697  01.01.2017
# 534                   Schirnding  95706  01.01.2017
# 596                   Thiersheim  95707  01.01.2017
# 604                      Tröstau  95709  01.01.2017
# 59                       Bamberg  96047  01.01.2018
# 566                    Sonneberg  96515  01.12.1997
# 683                     Würzburg  97070  01.01.2012
# 550                  Schweinfurt  97421  01.02.2019
# 587                         Suhl  98527  01.01.2015
# 290                      Ilmenau  98693         NaN
# 165                       Erfurt  99084  01.07.2018
# 637                       Weimar  99423  01.05.2009
# 442                   Nordhausen  99734         NaN
# 153                     Eisenach  99817  28.02.2002
#
#                                              Bemerkung
# 145                                                NaN
# 487                                                NaN
# 224                                                NaN
# 507                                                NaN
# 125                                                NaN
# 396                                                NaN
# 479                                                NaN
# 61                                                 NaN
# 217                                                NaN
# 282                                                NaN
# 126                                                NaN
# 572                                                NaN
# 226                                                NaN
# 121                                             FEHLER
# 352                                                NaN
# 16                                                 NaN
# 140                                                NaN
# 46   Bad Liebenwerda verfügt über keinen Mietspiege...
# 237                                                NaN
# 76                                                 NaN
# 32                                                 NaN
# 419                                                NaN
# 640                                                NaN
# 134                                                NaN
# 301                                                NaN
# 524                                                NaN
# 522                                                NaN
# 207                                                NaN
# 438  Es kommt der Mietspiegel des Landkreises Greiz...
# 678  Es kommt der Mietspiegel des Landkreises Greiz...
# ..                                                 ...
# 584                                                NaN
# 275                                                NaN
# 558                                                NaN
# 319                                                NaN
# 641                                                NaN
# 388                                                NaN
# 541                                                NaN
# 273                                                NaN
# 514                                                NaN
# 597                                                NaN
# 62   Die Stadt Bayreuth hat keinen eigenen Mietspie...
# 389                                                NaN
# 679                                                NaN
# 29                                                 NaN
# 40                                                 NaN
# 277                                                NaN
# 418                                                NaN
# 534                                                NaN
# 596                                                NaN
# 604                                                NaN
# 59                                                 NaN
# 566                                                NaN
# 683                                                NaN
# 550                                                NaN
# 587                                                NaN
# 290  Ein Mietspiegel für die Stadt Ilmenau gibt es ...
# 165                                                NaN
# 637                                                NaN
# 442  Für Nordhausen gibt es bisher keinen Mietspieg...
# 153                                                NaN
#
# [690 rows x 4 columns]

# %%
path_mietspiegel_storage = path_abs+'/mietspiegelAll.p'
ms_storage = pickle.load( open( path_mietspiegel_storage, "rb" ) )

# %%
for key in ms_storage:
    if ms_storage[key]:
        print(key)
        for i in range(len(ms_storage[key])):
            try:
                price_current_city = ms_storage[key][i].iloc[:,2]
            except:
                print('WARNING! ERROR ' + key)
                continue
            low = []
            mid = []
            upper = []
            idx_nans = []
            for idx, mietpreis in enumerate(price_current_city):
                splitted = [x.replace(',','.') for x in list(mietpreis.split(' - '))]
                if len(splitted[0]) > 4:
                    splitted = [x.replace(',','.') for x in list(mietpreis.split(' – '))]
                try:
                    splitted = [float(x) for x in splitted]
                except:
                    pass
                if len(splitted) == 1:
                    low.append(np.NaN)
                    mid.append(splitted[0])
                    upper.append(np.NaN)
                if len(splitted) == 2:
                    low.append(splitted[0])
                    mid.append(np.NaN)
                    upper.append(splitted[1])
                if len(splitted) == 3:
                    low.append(splitted[0])
                    mid.append(splitted[1])
                    upper.append(splitted[2])
            ms_storage[key][i].insert(ms_storage[key][i].shape[1], 'low_Price', low)
            ms_storage[key][i].insert(ms_storage[key][i].shape[1], 'mid_Price', mid)
            ms_storage[key][i].insert(ms_storage[key][i].shape[1], 'upper_Price', upper)
# Out:
# Aachen
# Aalen
# Abensberg
# Ahaus
# Ahlen
# Aichhalden
# Allersberg
# WARNING! ERROR Allersberg
# Alpen
# Alsdorf
# Altdorf (Niederbayern)
# Altdorf bei Nürnberg
# Altdorf, Kreis Böblingen
# Altena
# Altenburg
# Altenkirchen, Landkreis
# Altötting
# WARNING! ERROR Altötting
# Altusried
# WARNING! ERROR Altusried
# Andernach
# Angermünde
# Ansbach
# WARNING! ERROR Ansbach
# Arnoldsweiler
# Arnsberg
# Arzberg
# Aschaffenburg
# Ascheberg
# Aschersleben
# Attendorn
# Auerbach (Vogtland)
# Augsburg
# Aurich
# Bad Alexandersbad
# Bad Hindelang
# WARNING! ERROR Bad Hindelang
# Bad Kreuznach
# Bad Laasphe
# Bad Münstereifel
# Bad Oeynhausen
# Bad Salzuflen
# Bad Sassendorf (Gemeinde)
# Bad Waldsee
# Bad Wurzach
# Baden-Baden
# WARNING! ERROR Baden-Baden
# Balderschwang
# WARNING! ERROR Balderschwang
# Balve
# Bamberg
# Barsinghausen
# Bautzen
# Beckum
# Bedburg
# Bedburg-Hau
# Belm
# Bergen auf Rügen
# Bergheim
# Bergisch Gladbach
# Bergkamen
# Bergneustadt
# Berlin
# Bernau bei Berlin
# Bernburg (Saale)
# Bestwig
# Betzigau
# WARNING! ERROR Betzigau
# Beverungen
# Biberach an der Riß
# Bielefeld
# Bietigheim-Bissingen
# Billerbeck
# Bingen am Rhein
# Blaichach
# WARNING! ERROR Blaichach
# Bocholt
# Bochum
# Bolsterlang
# WARNING! ERROR Bolsterlang
# Bönen
# Bonn
# Borgholzhausen
# Bottrop
# Bramsche
# Brandenburg an der Havel
# Braunschweig
# Breckerfeld
# Bremerhaven
# Brüggen (Niederrhein)
# Brühl
# Büchenbach, Gemeinde
# WARNING! ERROR Büchenbach, Gemeinde
# Buchenberg
# WARNING! ERROR Buchenberg
# Buchholz in der Nordheide
# WARNING! ERROR Buchholz in der Nordheide
# Bünde
# Burbach (Siegerland)
# Burgberg
# WARNING! ERROR Burgberg
# Burgdorf
# Burgwedel
# Buxtehude
# Calau
# WARNING! ERROR Calau
# Castrop-Rauxel
# Chemnitz
# Coesfeld
# Coswig (Sachsen)
# Cottbus
# Cuxhaven
# Dachau
# Damme (Dümmer)
# Darmstadt
# Datteln
# Dautphetal
# WARNING! ERROR Dautphetal
# Delmenhorst
# Dessau-Roßlau
# Detmold
# Dietmannsried
# WARNING! ERROR Dietmannsried
# Dinslaken
# Dissen am Teutoburger Wald
# Döbeln
# Dormagen
# Dorsten
# Dortmund
# Dreieich
# Dresden
# Duisburg
# Dülmen
# Durach
# WARNING! ERROR Durach
# Düren
# Düsseldorf
# Eberswalde
# Edemissen
# Eisenach
# Eisenhüttenstadt
# Elsdorf (Rheinland)
# Emmerich am Rhein
# Emsdetten
# Engelskirchen
# Enger
# Ennepetal
# Ense
# Erding
# WARNING! ERROR Erding
# Erftstadt
# Erfurt
# Erkelenz
# Erkrath
# Erlangen
# Eschborn
# WARNING! ERROR Eschborn
# Eschweiler
# Essen
# Esslingen am Neckar
# Euskirchen
# Fellbach
# Finnentrop
# Fischen
# WARNING! ERROR Fischen
# Flensburg
# WARNING! ERROR Flensburg
# Frankenthal (Pfalz)
# Frankfurt (Oder)
# Frankfurt am Main
# Frechen
# Freiberg
# Freiburg im Breisgau
# Freudenberg (Siegerland)
# Friedrichshafen
# Friesoythe
# WARNING! ERROR Friesoythe
# Fröndenberg (Ruhr)
# Fürstenwalde/Spree
# Fürth
# Gangelt (Gemeindegebiet)
# Garbsen
# Garching
# Gehrden
# Geilenkirchen
# Geldern
# Gelsenkirchen
# Georgensgmünd
# WARNING! ERROR Georgensgmünd
# Georgsmarienhütte
# Gera
# Germering
# Germersheim
# Gevelsberg
# Gladbeck
# Goch
# Görlitz
# Göttingen
# WARNING! ERROR Göttingen
# Grefrath
# Greifswald
# Greiz (Landkreis)
# Greven
# Grevenbroich
# Großenhain
# Großkrotzenburg
# Guben
# Gummersbach
# Gütersloh
# Gütersloh, Nordkreis
# WARNING! ERROR Gütersloh, Nordkreis
# Haan
# Hagen
# Hagnau am Bodensee
# Hainburg
# WARNING! ERROR Hainburg
# Haldensleben
# Haldenwang (Allgäu)
# WARNING! ERROR Haldenwang (Allgäu)
# Halle (Saale)
# Halle (Westfalen)
# Haltern am See
# Halver
# Hamburg
# Hamm
# Hamminkeln
# Hanau
# Hannover
# Harsewinkel
# Hattingen
# Havixbeck
# Heideck
# WARNING! ERROR Heideck
# Heidelberg
# Heilbronn
# Heiligenhaus
# Heinsberg
# Hemmingen (Niedersachsen)
# Hennigsdorf
# Herdecke an der Ruhr
# Herford
# Herne
# Hersbruck
# Herten
# Herzebrock-Clarholz
# Herzogenrath
# Hilchenbach
# Hilden
# Hildesheim
# Hilpoltstein
# WARNING! ERROR Hilpoltstein
# Höchstädt im Fichtelgebirge
# Hof
# Hohen Neuendorf
# WARNING! ERROR Hohen Neuendorf
# Hohenberg an der Eger
# Holzwickede
# Horgenzell
# Höxter
# Hoyerswerda
# Hückelhoven
# Hückeswagen
# Hünxe, Gemeinde
# Hürth
# Ibbenbüren
# Idar-Oberstein
# WARNING! ERROR Idar-Oberstein
# Immenstaad am Bodensee (Gemeinde)
# Immenstadt im Allgäu
# WARNING! ERROR Immenstadt im Allgäu
# Ingelheim am Rhein
# Ingolstadt
# WARNING! ERROR Ingolstadt
# Iserlohn
# WARNING! ERROR Iserlohn
# Isernhagen
# Issum
# Jena
# Jessen (Elster)
# Jülich
# Kaiserslautern
# Kalkar
# Kamen
# Kamp-Lintfort
# Karlsfeld
# Karlsruhe
# Kassel
# WARNING! ERROR Kassel
# Kempen
# Kempten
# Kerken
# Kerpen
# Kevelaer
# Kiel
# Kierspe
# Kirchdorf bei Sulingen
# Kirchenlamitz
# Kirchham
# WARNING! ERROR Kirchham
# Kirchhundem
# Kleve
# Koblenz
# Köln
# Konstanz
# Korbach
# WARNING! ERROR Korbach
# Korschenbroich
# Krefeld
# Kreuztal
# Laatzen
# Landau in der Pfalz
# Landshut
# Langenberg
# Langenfeld
# Langenhagen
# Langenzenn
# Langerwehe
# Lauben
# WARNING! ERROR Lauben
# Lauf an der Pegnitz
# Lehrte
# Leipzig
# Lemgo
# Lengede
# Lengerich (Westfalen)
# Lennestadt
# Leonberg
# Leutkirch im Allgäu
# Leverkusen
# Lindlar
# Lingen (Ems)
# Lippetal
# Lippstadt
# Löhne
# Lorch
# Lörrach
# WARNING! ERROR Lörrach
# Lübbecke (Altkreis)
# Lübeck
# Lüdenscheid
# Lüdinghausen
# Ludwigsburg
# Ludwigsfelde
# Ludwigshafen am Rhein
# Lüneburg
# Lünen
# Magdeburg
# Maintal
# Mainz
# Mannheim
# Marienheide
# Markdorf
# Marktleuthen
# Marktredwitz
# Marl
# Marsberg
# Mechernich
# Meckenbeuren
# Meersburg
# Meinerzhagen
# WARNING! ERROR Meinerzhagen
# Meißen
# Melle
# Menden (Sauerland)
# WARNING! ERROR Menden (Sauerland)
# Meppen
# Merzenich
# Mettmann
# Minden
# Missen-Wilhams
# WARNING! ERROR Missen-Wilhams
# Moers
# Möhnesee, Gemeinde
# Mönchengladbach
# Monheim am Rhein
# Monschau
# Morsbach
# Mülheim an der Ruhr
# München
# Münster
# Nachrodt-Wiblingwerde
# WARNING! ERROR Nachrodt-Wiblingwerde
# Nagel
# Naumburg (Saale)
# Netphen
# Nettetal
# Neu-Ulm
# WARNING! ERROR Neu-Ulm
# Neubrandenburg
# Neuenrade
# WARNING! ERROR Neuenrade
# Neuhausen auf den Fildern
# Neukirch
# Neukirchen-Vluyn
# Neunkirchen
# Neuss
# Neustadt am Rübenberge
# Neustadt an der Weinstraße
# Neuwied
# Niederkrüchten
# Niederzier
# Norden
# Norderstedt
# Nordkirchen
# Nottuln
# Nümbrecht
# Nürnberg
# Oberhausen
# Obermaiselstein
# WARNING! ERROR Obermaiselstein
# Oberstaufen
# WARNING! ERROR Oberstaufen
# Oberstdorf
# WARNING! ERROR Oberstdorf
# Oberursel
# WARNING! ERROR Oberursel
# Oelde
# Oer-Erkenschwick
# Offenbach am Main
# Offenburg
# Ofterschwang
# WARNING! ERROR Ofterschwang
# Oldenburg
# Olfen
# Olpe
# Oranienburg
# Osnabrück
# Oy-Mittelberg
# WARNING! ERROR Oy-Mittelberg
# Paderborn
# Parchim
# Passau
# Pattensen
# Peine
# Petershagen
# Pfaffenhofen an der Ilm
# Pforzheim
# Pirna
# Plauen
# Plettenberg
# WARNING! ERROR Plettenberg
# Porta Westfalica
# Potsdam
# Prenzlau
# Pulheim
# Radebeul
# Radevormwald
# Radolfzell
# Rastatt
# Ravensburg
# Recklinghausen
# Rees
# Regensburg
# Reichshof
# Reinbek
# Remscheid
# Remshalden
# WARNING! ERROR Remshalden
# Rendsburg
# WARNING! ERROR Rendsburg
# Rettenberg
# WARNING! ERROR Rettenberg
# Reutlingen
# Rheda-Wiedenbrück
# Rheinberg
# Rheine
# Rheurdt
# Riesa
# Rietberg
# Roetgen
# Ronnenberg
# Rosendahl
# Röslau
# Roßtal
# Rostock
# Roth
# Röttenbach
# WARNING! ERROR Röttenbach
# Rottweil
# Rudersberg
# Rudolstadt
# Saalfeld (Saale)
# Sankt Augustin
# Sassnitz
# Schalksmühle
# WARNING! ERROR Schalksmühle
# Schirnding
# Schloß Holte-Stukenbrock
# Schmelz
# Schöneiche bei Berlin
# Schönwald
# Schorndorf
# Schramberg
# Schwabach
# Schwalmtal
# Schwarzenbek
# WARNING! ERROR Schwarzenbek
# Schwedt / Oder
# Schweinfurt
# Schwelm
# Schwerin
# Schwerte
# Seelze
# Sehnde
# Selb
# Selm
# Senden
# Siegen
# Simmerath (Gemeinde)
# Sindelfingen
# Soest
# Solingen
# Sonneberg
# Sonsbeck
# Sonthofen
# Spalt
# WARNING! ERROR Spalt
# Speyer
# Spremberg
# Springe
# Sprockhövel
# Steinfurt / Münsterland
# Steinhagen
# Stolberg
# Straelen
# Stralsund
# Straubing
# Strausberg
# Stuttgart
# Suhl
# Sulzberg
# WARNING! ERROR Sulzberg
# Sundern
# Taunusstein
# Teltow
# Thalmässing, Markt
# WARNING! ERROR Thalmässing, Markt
# Thiersheim
# Thierstein
# Tönisvorst
# Trier
# Troisdorf
# Tröstau
# Tübingen
# Tuttlingen
# Überlingen
# Uetze
# Ulm
# Unna
# Verbandsgemeinde Loreley
# Verden
# Verl
# Versmold
# Vettweiß (Gemeindegebiet)
# Viersen
# Villingen-Schwenningen
# Vlotho
# Voerde
# Wachtendonk
# Waiblingen
# Waldbröl
# Wallenhorst
# Waltenhofen
# WARNING! ERROR Waltenhofen
# Waltrop
# Wangen im Allgäu
# Warendorf
# Warstein
# Wedemark
# Weeze
# Wegberg
# Weimar
# Weinstadt
# Weißenfels
# Weißenstadt
# Weitnau
# WARNING! ERROR Weitnau
# Welver
# Welzheim
# Wendelstein
# Wennigsen (Gemeinde)
# Werdohl
# WARNING! ERROR Werdohl
# Werl
# Werne
# Wertach
# WARNING! ERROR Wertach
# Werther (Westfalen)
# Wesel
# Wesseling
# Wetter (Ruhr)
# Wickede (Ruhr)
# Wiehl
# Wiesbaden
# Wiggensbach
# WARNING! ERROR Wiggensbach
# Wildpoldsried
# WARNING! ERROR Wildpoldsried
# Willich
# Wilnsdorf
# Winnenden
# Winsen (Luhe)
# Wipperfürth
# Wismar
# Witten
# Worms
# Wülfrath
# Wunsiedel
# Wunstorf
# Wuppertal
# Würzburg
# Xanten
# Zirndorf
# Zülpich
# Zwickau

# %%
ms_storage['Jena'][0]
# Out:
#    Vergleichsmiete für 65m²-Wohnungen* Baujahr                 €/m²  \
# 0                                  NaN    1905   6,50 - 7,63 - 8,90
# 1                                  NaN    1925   6,50 - 7,63 - 8,90
# 2                                  NaN    1955   5,86 - 6,55 - 7,10
# 3                                  NaN    1965   5,86 - 6,55 - 7,10
# 4                                  NaN    1975   4,79 - 5,31 - 6,00
# 5                                  NaN    1985   4,79 - 5,31 - 6,00
# 6                                  NaN    1995   6,93 - 7,80 - 8,74
# 7                                  NaN    2000   6,93 - 7,80 - 8,74
# 8                                  NaN    2005  7,39 - 8,82 - 10,39
# 9                                  NaN    2010  7,39 - 8,82 - 10,39
# 10                                 NaN    2015  7,39 - 8,82 - 10,39
#
#     low_Price  mid_Price  upper_Price
# 0        6.50       7.63         8.90
# 1        6.50       7.63         8.90
# 2        5.86       6.55         7.10
# 3        5.86       6.55         7.10
# 4        4.79       5.31         6.00
# 5        4.79       5.31         6.00
# 6        6.93       7.80         8.74
# 7        6.93       7.80         8.74
# 8        7.39       8.82        10.39
# 9        7.39       8.82        10.39
# 10       7.39       8.82        10.39

# %%
df_mietspiegelLookUp.to_csv(path_abs+'/metaInfosAllCleaned.csv')

# %%
#pickle.dump(storage, open( path_abs+"/mietspiegelAll.p", "wb" ) )
pickle.dump(ms_storage, open( path_abs+"/mietspiegelAllCleaned.p", "wb" ) )
